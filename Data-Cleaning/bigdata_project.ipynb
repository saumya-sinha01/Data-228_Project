# %%
import pandas as pd

# %%
df = pd.read_csv('US1.csv')
# Out:
# /Users/mounicaayalasomayajula/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df = df.fillna("")

# %%
df1 = df.dropna(how='all')

# %%
print("total number of rows are {rows}.".format(rows=len(df)))
# Out:
# total number of rows are 1048574.

# %%
print(df.columns)
# Out:
# Index(['2130833', 'McArthur Reef', 'McArthur Reef.1', 'Unnamed: 3', '52.06667',
#        '177.86667', 'U', 'RFU', 'US', 'Unnamed: 9', 'AK', '16', 'Unnamed: 12',
#        'Unnamed: 13', '0', 'Unnamed: 15', '-9999', 'Asia/Kamchatka', '7/5/16'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# 2130833            0
# McArthur Reef      0
# McArthur Reef.1    0
# Unnamed: 3         0
# 52.06667           0
# 177.86667          0
# U                  0
# RFU                0
# US                 0
# Unnamed: 9         0
# AK                 0
# 16                 0
# Unnamed: 12        0
# Unnamed: 13        0
# 0                  0
# Unnamed: 15        0
# -9999              0
# Asia/Kamchatka     0
# 7/5/16             0
# dtype: int64

# %%
df.head()
# Out:
#    2130833            McArthur Reef          McArthur Reef.1  \
# 0  3577483              The Narrows              The Narrows
# 1  3831601         Nantucket Shoals         Nantucket Shoals
# 2  3831610  Little Stellwagen Basin  Little Stellwagen Basin
# 3  3831661             Cashes Ledge             Cashes Ledge
# 4  3831676               Ammen Rock               Ammen Rock
#
#                Unnamed: 3  52.06667  177.86667  U   RFU  US Unnamed: 9  AK 16  \
# 0             The Narrows  18.37502  -64.72517  H   CHN  US         VG   0
# 1                          41.06917  -69.67983  U  SHSU  US             MA
# 2                          42.11667  -70.28333  U  BSNU  US              0
# 3  Cash Ledge,Cashe Ledge  42.91328  -68.95380  U  RDGU  US
# 4                          42.89129  -68.94357  U   RFU  US
#
#   Unnamed: 12 Unnamed: 13  0 Unnamed: 15  -9999     Asia/Kamchatka   7/5/16
# 0                          0              -9999  America/St_Thomas  11/6/18
# ...

# %%
df=df.dropna(how='any',axis=0)

# %%
df.head()
# Out:
#    2130833            McArthur Reef          McArthur Reef.1  \
# 0  3577483              The Narrows              The Narrows
# 1  3831601         Nantucket Shoals         Nantucket Shoals
# 2  3831610  Little Stellwagen Basin  Little Stellwagen Basin
# 3  3831661             Cashes Ledge             Cashes Ledge
# 4  3831676               Ammen Rock               Ammen Rock
#
#                Unnamed: 3  52.06667  177.86667  U   RFU  US Unnamed: 9  AK 16  \
# 0             The Narrows  18.37502  -64.72517  H   CHN  US         VG   0
# 1                          41.06917  -69.67983  U  SHSU  US             MA
# 2                          42.11667  -70.28333  U  BSNU  US              0
# 3  Cash Ledge,Cashe Ledge  42.91328  -68.95380  U  RDGU  US
# 4                          42.89129  -68.94357  U   RFU  US
#
#   Unnamed: 12 Unnamed: 13  0 Unnamed: 15  -9999     Asia/Kamchatka   7/5/16
# 0                          0              -9999  America/St_Thomas  11/6/18
# ...

# %%
df2=pd.read_csv('US2.csv')
# Out:
# /Users/mounicaayalasomayajula/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (9,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df2 = df2.fillna("")

# %%
df22 = df.dropna(how='all')

# %%
print("total number of rows are {rows}.".format(rows=len(df2)))
# Out:
# total number of rows are 1048574.

# %%
print(df2.columns)
# Out:
# Index(['5107285', 'Arabia', 'Arabia.1', 'Unnamed: 3', '42.53397', '-74.6357',
#        'P', 'PPL', 'US', 'Unnamed: 9', 'NY', '95', '38440', 'Unnamed: 13', '0',
#        '621', '626', 'America/New_York', '5/23/17'],
#       dtype='object')

# %%
print(df2.isnull().sum())
# Out:
# 5107285             0
# Arabia              0
# Arabia.1            0
# Unnamed: 3          0
# 42.53397            0
# -74.6357            0
# P                   0
# PPL                 0
# US                  0
# Unnamed: 9          0
# NY                  0
# 95                  0
# 38440               0
# Unnamed: 13         0
# 0                   0
# 621                 0
# 626                 0
# America/New_York    0
# 5/23/17             0
# dtype: int64

# %%
df2.head()
# Out:
#    5107285           Arabia         Arabia.1    Unnamed: 3  42.53397  \
# 0  5107286  Arbuckle Hollow  Arbuckle Hollow                42.21147
# 1  5107287    Anthony Point    Anthony Point                44.34727
# 2  5107288     Arbutus Lake     Arbutus Lake                40.52297
# 3  5107289     Arbutus Pond     Arbutus Pond                43.98786
# 4  5107290           Arcade           Arcade  Arcade,China  42.53395
#
#    -74.6357  P   PPL  US Unnamed: 9  NY     95   38440 Unnamed: 13     0  \
# 0 -74.90877  T   VAL  US             NY   25.0                         0
# 1 -75.90495  T  CAPE  US             NY   45.0                         0
# 2 -74.17815  H    LK  US             NY   85.0                         0
# 3 -74.24170  H    LK  US             NY   31.0                         0
# 4 -78.42307  P   PPL  US             NY  121.0  2418.0              1986
#
#      621  626  America/New_York   5/23/17
# 0  491.0  498  America/New_York   1/15/06
# ...

# %%
df3 = pd.read_csv('US3.csv')
# Out:
# /Users/mounicaayalasomayajula/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df3.head()
# Out:
#    8101720                Marion Fire Department Headquarters  \
# 0  8101721                    East Brookfield Fire Department
# 1  8101722     Milford Fire Department Station 2 Headquarters
# 2  8101723      Lowell Fire Department Station 3 Headquarters
# 3  8101724                             Buckland Fire District
# 4  8101725  Provincetown Fire Department Station 1 Headqua...
#
#                Marion Fire Department Headquarters.1 Unnamed: 3  41.70599  \
# 0                    East Brookfield Fire Department        NaN  42.22600
# 1     Milford Fire Department Station 2 Headquarters        NaN  42.14518
# 2      Lowell Fire Department Station 3 Headquarters        NaN  42.64711
# 3                             Buckland Fire District        NaN  42.56613
# 4  Provincetown Fire Department Station 1 Headqua...        NaN  42.04944
#
#    -70.7676  S  BLDG  US Unnamed: 9  MA    23    38540  Unnamed: 13  0     10  \
# ...

# %%
print("total number of rows are {rows}.".format(rows=len(df3)))
# Out:
# total number of rows are 142599.
