# %%
import pandas as pd

# %%
df = pd.read_csv('AllTrails-data-nationalpark.csv')

# %%
df = df.fillna("")

# %%
df1 = df.dropna(how='all')

# %%
print("total number of rows are {rows}.".format(rows=len(df)))
# Out:
# total number of rows are 3313.

# %%
print(df.columns)
# Out:
# Index(['trail_id', 'name', 'area_name', 'city_name', 'state_name',
#        'country_name', '_geoloc', 'popularity', 'length', 'elevation_gain',
#        'difficulty_rating', 'route_type', 'visitor_usage', 'avg_rating',
#        'num_reviews', 'features', 'activities', 'units'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# trail_id             0
# name                 0
# area_name            0
# city_name            0
# state_name           0
# country_name         0
# _geoloc              0
# popularity           0
# length               0
# elevation_gain       0
# difficulty_rating    0
# route_type           0
# visitor_usage        0
# avg_rating           0
# num_reviews          0
# features             0
# activities           0
# units                0
# dtype: int64

# %%
df.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#               city_name state_name   country_name  \
# 0                Seward     Alaska  United States
# 1  Denali National Park     Alaska  United States
# 2                Seward     Alaska  United States
# 3  Denali National Park     Alaska  United States
# 4  Denali National Park     Alaska  United States
#
#                                 _geoloc  popularity     length  \
# 0  {'lat': 60.18852, 'lng': -149.63156}     24.8931  15610.598
# 1  {'lat': 63.73049, 'lng': -148.91968}     18.0311   6920.162
# ...

# %%
df2=pd.read_csv('All-National-Parks-Visitation-1904-2016.csv')

# %%
df2 = df2.fillna("")

# %%
df22 = df2.dropna(how='all')

# %%
print("total number of rows are {rows}.".format(rows=len(df2)))
# Out:
# total number of rows are 21560.

# %%
 print(df2.columns)
# Out:
# Index(['Created By', 'Measure Selector', 'Year', 'Date Edit', 'ScrapeURL',
#        'GIS Notes', 'Gnis Id', 'Geometry', 'Metadata', 'Number of Records',
#        'Parkname', 'Region', 'State', 'Unit Code', 'Unit Name', 'Unit Type',
#        'Visitors', 'YearRaw'],
#       dtype='object')

# %%
df2.head()
# Out:
#   Created By  Measure Selector                  Year  Date Edit  \
# 0     Legacy                 1  1/1/1904 12:00:00 AM  4/22/2015
# 1     Legacy                 1  1/1/1941 12:00:00 AM  4/22/2015
# 2     Legacy                 1  1/1/1961 12:00:00 AM  4/22/2015
# 3     Legacy                 1  1/1/1935 12:00:00 AM  4/22/2015
# 4     Legacy                 1  1/1/1982 12:00:00 AM  4/22/2015
#
#                                            ScrapeURL  \
# 0  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 1  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 2  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 3  https://irma.nps.gov/Stats/SSRSReports/Park%20...
# 4  https://irma.nps.gov/Stats/SSRSReports/Park%20...
#
#                                            GIS Notes  Gnis Id      Geometry  \
# 0  LEGACY: contact allen_mccoy@nps.gov for additi...  1163670       POLYGON
# 1  LEGACY: contact allen_mccoy@nps.gov for additi...  1531834  MULTIPOLYGON
# ...
